# %% [markdown]
# #### W4A1:
# [SumOfNumBers]
# Viết chương trình Python sử dụng một trong 2 loại vòng lặp for hoặc while để
# tính tống các số nguyên từ 1 đến n. (n <= 1000)

# %%
n = int(input())
if n <= 1000:
    a = 0
    for i in range (1,n+1):
        a += i
    print(a)
    b = 0
    c = 0
    while c <= n:
        c, b = c+1, b+c
    print (b)
# Out:
# 5050
# 5050

# %% [markdown]
# #### W4A2:
# [PrimeNumber]
# Viết chương trình nhập vào một số tới khi được một số nguyên dương thì thôi. Kiểm tra số này có phải là số nguyên tố hay không?

# %%
a = int(input())
while a < 0:
    a = int(input())
if a < 2:
    print("Đây không phải là số nguyên tố")
else:
    for i in range(2, int(a**0.5+1)):
        if a%i == 0:
            print("Đây không phải là số nguyên tố")
            break
    else:
        print("Đây là số nguyên tố")
# Out:
# Đây là số nguyên tố

# %% [markdown]
# #### W4A3:
# [Factorial]
# Viết chương trình tính giai thừa của một số nguyên n cho trước (n! = 1 * 2 * ... * n) với 0 < n < 100.

# %%
n = int(input())
c = 1
for i in range(1,n+1):
    c *= i
print(c)
# Out:
# 6

# %% [markdown]
# #### W4A4:
# [Counting Digits]
# Viết chương trình nhập vào một số nguyên n và in ra màn hình số chữ số (trừ dấu) của số đó. Không dùng kiểu dữ liệu string.

# %%
a = int(input())
b = 0
if a<0:
    a = -a
while a != 0:
    b += 1
    a = a//10
print(b)
# Out:
# 5

# %% [markdown]
# #### W4A5:
# [MeaningOfLife]
# Khi Douglas Adam viết cuốn sách, The Hitchhiker's Guide to the Galaxy, ông ta đã thêm vào đó một vài lời nói đùa, và theo năm tháng nó đã trở nên nổi tiếng hơn cả bản thân cuốn tiểu thuyết: “Câu trả lời cho câu hỏi lớn nhất về sự sống, về vũ trụ và tất cả mọi thứ là 42.” Một vài người cuồng tín đã tốn hàng năm trời, với mọi cố gắng nỗ lực để gán ghép nghĩa, biểu trưng cho con số 42 và các “sự cố” liên quan đến nó.
#
# Xuyên suốt lịch sử, các con số được gán cho những ý nghĩa đặc biệt nào đó. Plato gọi việc nghiên cứu các biểu tượng số học là level cao nhất của tri thức. Trong khi Pythagoras tin rằng các con số đều có linh hồn cũng như sức mạnh kì diệu. Trong khi đó, hàng triệu người hâm hộ Hitchhiker cho đến ngày nay vẫn kiên trì giải mã những thứ họ cho rằng đó là những động cơ bí mật của Adams.
#
# Hãy viết một chương trình nhận vào một số nguyên dương n và một dãy gồm n số nguyên. Nếu n số nguyên đó có số 42 thì in ra màn hình dòng chữ "I've found the meaning of life!", ngược lại in ra dòng chữ "It's a joke!".

# %%
n = int(input())
a = list(map(int,input().split()))
if len(a) == n:
    if 42 in a:
        print("I've found the meaning of life!")
    else:
        "It's a joke!"
else:
    print("Dãy số có số số nguyên không phù hợp")
# Out:
# Dãy số có số số nguyên không phù hợp

# %% [markdown]
# #### W4A6:
# [SumPrimesInRange]
# Nhập hai số nguyên dương a, b (a ≤ b). Hãy tính tổng các số nguyên tố trong đoạn [a, b]. Mỗi dòng là một bộ test (a b).

# %%
a,b = map(int,input().split())
c = 0
if a <= b:
    for i in range(a,b+1):
        if i != 1:
            for h in range(2,int(i**0.5)+1):
                if i%h == 0:
                    break
            else:
                c += i
    print(c)
else:
    print("Hai số nhập vào không hợp lệ")
# Out:
# 17

# %% [markdown]
# #### W4A7:
# [LargestPrimeFactor]
# Nhập vào số nguyên dương n (n ≥ 2). Hãy in ra ước số nguyên tố lớn nhất của n.

# %%
n = int(input())
if n >= 2:
    c = 0
    for i in range(2,n+1):
        if n%i == 0:
            for h in range(2,int(i**0.5)+1):
                if i%h == 0:
                    break
            else:
                if i > c:
                    c = i
    print(c)
# Out:
# 9973

# %% [markdown]
# #### W4A8:
# [ReverseAddPalindrome]
# Nhập số nguyên dương n. Lặp lại phép toán n = n + reverse(n) cho đến khi n là số đối xứng (palindrome). In ra số bước và giá trị palindrome thu được.

# %%
n = int(input())
if n > 0:
    reversed_n = int(str(n)[::-1])
    c = 0
    while True:
        reversed_n = int(str(n)[::-1])
        n = n + reversed_n
        c +=1
        if str(n) == str(n)[::-1]:
            break
print(f"Số bước là {c}, giá trị thu được là {n}")
# Out:
# Số bước là 2, giá trị thu được là 133331

# %% [markdown]
# #### W4A9:
# [PerfectSquares DistinctDigits]
# Nhập vào số nguyên dương n. In ra tất cả các số chính phương <= n có các chữ số đôi một khác nhau (in theo thứ tự tăng dần, cùng hàng, cách nhau bởi một dấu cách). Nếu không có, in ra (no number).

# %%
n = int(input())
a = 0
for i in range(1, n+1):
    if int(i**0.5) == i**0.5:
        if len(str(i)) == len(set(str(i))):
            a += 1
            print(i,end=" ")
if a == 0:
    print("No number")
# Out:
# 1 4 9 16 25 36 49 64 81 169 196 256 289 324 361 529 576 625 729 784 841 961

# %% [markdown]
# #### W4A10:
# [LongestCollatzUpToN]
# Nhập vào số nguyên dương n. Tìm số x trong [1, n] có độ dài dãy Collatz lớn nhất và in ra x cùng độ dài dãy tương ứng (x L). Nếu có nhiều số cùng độ dài, chọn số nhỏ nhất.

# %%
n = int(input())
if n > 0:
    d = n
    b = 1
    for i in range (1, n+1):
        a = 0
        c = i
        while c > 1:
            if c%2 == 0:
                c /= 2
            else:
                c = 3*c + 1
            10
            a += 1
        if a > b:
            b = a
            d = i
    print(f"Số cần chọn là {d}, với độ dài dãy Collatz là {b}")
# Out:
# Số cần chọn là 18, với độ dài dãy Collatz là 20

# %% [markdown]
# #### W4A11:
# [EvenDivisors]
# Viết chương trình đếm số lượng ước số chẵn của số nguyên dương n với $n<10^{\wedge}6$.

# %%
n = int(input())
if n > 0:
    a = 0
    for i in range(1,n+1):
        if n%i == 0 and i%2 == 0:
            a += 1
    print(a)
# Out:
# 2

# %% [markdown]
# #### W4A12:
# [Interest]
# Một người có tài khoản tiết kiệm ở ngân hàng và gửi vào X đồng với lãi suất là 0.7% mỗi tháng. Viết chương trình tính số tiền sau N tháng người ấy rút được (cả gốc và lãi, bỏ qua phần lẻ thập phân).

# %%
x = float(input())
n = int(input())
print(f"{x*((107/100)**n):.0f}")
# Out:
# 11

# %% [markdown]
# #### W4A13:
# [ClosePairNumber]
# Hai số nguyên dương tạo thành một cặp số thân thiết khi chúng tuân theo quy luật: Số này bằng tông tất cả các ước của số kia (trừ chính nó) và ngược lại.
# Ví dụ 220 và 284 là một cặp số thân thiết
# 220 ngoài chính nó ra, nó còn có 11 ước số khác là: 1, 2, 4, 5, 10, 11, 20, 44, 55, 110. Tổng của 11 ước này cho chúng ta 284
# 284 ngoài bản thân nó, còn có 5 ước số khác là: 1, 2, 4, 71, 142. Tổng của chúng vừa đúng bằng 220
# Nhập hai số từ bàn phím và kiểm tra xem chúng có phải là cặp số thân thiết không. Nếu có, in ra màn hình "true", ngược lại, in ra "false"

# %%
a,b = map(int,input().split())
tong_uoc_a = 0
tong_uoc_b = 0
for i in range(1,a):
    if a%i == 0:
        tong_uoc_a += i
for h in range(1,b):
    if b%h == 0:
        tong_uoc_b += h
if a == tong_uoc_b and b == tong_uoc_a:
    print("true")
else:
    print("false")
# Out:
# true

# %% [markdown]
# #### W4A14:
# [GCD]
# Cho hai số m và n là hai số nguyên dương nhập từ bàn phím. Viết chương trình tìm ước chung lớn nhất của hai số m và n.

# %%
m,n = map(int,input())
while m != 0:
    m, n = n, m%n
print(m)

# %% [markdown]
# #### W4A15:
# [ChickenAndDog]
# "Vừa gà vừa chó,
# Bó lại cho tròn,
# Ba mươi sáu con,
# Một trăm chân chẫn"
# Từ bài toán dân gian trên, mở rộng thành chương trình nhận đầu vào là tổng số con và tổng số chân của gà và chó. Nếu tìm được số phù hợp, in ra số lượng gà và số lượng chó. Ngược lại, in ra "invalid".

# %%
a,b = map(int,input().split())
so_ga = (4*a-b)/2
so_cho = a - so_ga
if 0 < so_ga and 0 < so_cho and int(so_ga) == so_ga and int(so_cho) == so_cho:
    print(f"Số gà là {so_ga}, số chó là {so_cho}")
else:
    print("invalid")
# Out:
# Số gà là 22.0, số chó là 14.0
